# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)

# %%
# !pip install hume
# !pip install hume["stream"]
# Out:
# Requirement already satisfied: hume in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from hume) (2.31.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.3.0 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from hume) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume) (2022.12.7)
# Requirement already satisfied: hume[stream] in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from hume[stream]) (2.31.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.3.0 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from hume[stream]) (4.8.0)
# Requirement already satisfied: websockets<11.0,>=10.3 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from hume[stream]) (10.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume[stream]) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume[stream]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume[stream]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.28.2->hume[stream]) (2022.12.7)

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\might\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.24.2)

# %%
LUAN_API_KEY = "0BU3yyyBmwT7r6uXV8uh7q17pjNQofKCUnDA2ZfNAGl5Rn8U"

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
import base64
from pathlib import Path

def encode_data(filepath: Path) -> str:
    with Path(filepath).open('rb') as fp:
        bytes_data = base64.b64encode(fp.read())
        encoded_data = bytes_data.decode("utf-8")
        return encoded_data

# %%
import asyncio

from hume import HumeStreamClient, StreamSocket
from hume.models.config import FaceConfig

# %%
async def main(filepath):
    client = HumeStreamClient(LUAN_API_KEY)
    config = FaceConfig(identify_faces=True)
    async with client.connect([config]) as socket:
        result = await socket.send_file(filepath)
        with open("stream_output.txt", "w") as output_file:
            output_file.write(str(result))

# %%
import os
import cv2

webcam = cv2.VideoCapture(0)

dataframes = []
timestep = 1

for i in range(31):
    check, frame = webcam.read()
    cv2.imwrite("", frame)

# %%
await main("carol.jpg")

# %%
with open("stream_output.txt", "r") as file:
    output_str = file.read().replace("\'", "\"").replace("None", "0")
with open("stream_output.txt", "w") as file:
    file.write(output_str)

# %%
dict = json.loads(output_str)
dict["face"]["predictions"][0]["emotions"]
# Out:
# [{'name': 'Admiration', 'score': 0.21992361545562744},
#  {'name': 'Adoration', 'score': 0.2841189503669739},
#  {'name': 'Aesthetic Appreciation', 'score': 0.08644698560237885},
#  {'name': 'Amusement', 'score': 0.8104043006896973},
#  {'name': 'Anger', 'score': 0.021307600662112236},
#  {'name': 'Anxiety', 'score': 0.04699099808931351},
#  {'name': 'Awe', 'score': 0.07179002463817596},
#  {'name': 'Awkwardness', 'score': 0.15837445855140686},
#  {'name': 'Boredom', 'score': 0.05779407173395157},
#  {'name': 'Calmness', 'score': 0.19809575378894806},
#  {'name': 'Concentration', 'score': 0.10381373763084412},
#  {'name': 'Contemplation', 'score': 0.05439431592822075},
#  {'name': 'Confusion', 'score': 0.09368330985307693},
#  {'name': 'Contempt', 'score': 0.06445620954036713},
#  {'name': 'Contentment', 'score': 0.29041582345962524},
#  {'name': 'Craving', 'score': 0.03693166375160217},
#  {'name': 'Determination', 'score': 0.046610090881586075},
#  {'name': 'Disappointment', 'score': 0.055513784289360046},
#  {'name': 'Disgust', 'score': 0.031424783170223236},
#  {'name': 'Distress', 'score': 0.05765277147293091},
#  {'name': 'Doubt', 'score': 0.0645204707980156},
#  {'name': 'Ecstasy', 'score': 0.18097618222236633},
#  {'name': 'Embarrassment', 'score': 0.07423879951238632},
#  {'name': 'Empathic Pain', 'score': 0.030312353745102882},
#  {'name': 'Entrancement', 'score': 0.08441581577062607},
#  {'name': 'Envy', 'score': 0.025140076875686646},
#  {'name': 'Excitement', 'score': 0.4825372099876404},
#  {'name': 'Fear', 'score': 0.03264304995536804},
#  {'name': 'Guilt', 'score': 0.022396638989448547},
#  {'name': 'Horror', 'score': 0.018799811601638794},
#  {'name': 'Interest', 'score': 0.3824896216392517},
#  {'name': 'Joy', 'score': 0.8641487956047058},
#  {'name': 'Love', 'score': 0.5511711835861206},
#  {'name': 'Nostalgia', 'score': 0.07608338445425034},
#  {'name': 'Pain', 'score': 0.05293821543455124},
#  {'name': 'Pride', 'score': 0.1511441320180893},
#  {'name': 'Realization', 'score': 0.08867352455854416},
#  {'name': 'Relief', 'score': 0.11885799467563629},
#  {'name': 'Romance', 'score': 0.10711023211479187},
#  {'name': 'Sadness', 'score': 0.039249174296855927},
#  {'name': 'Satisfaction', 'score': 0.429100900888443},
#  {'name': 'Desire', 'score': 0.06063579022884369},
#  {'name': 'Shame', 'score': 0.028823742642998695},
#  {'name': 'Surprise (negative)', 'score': 0.017276277765631676},
#  {'name': 'Surprise (positive)', 'score': 0.029604850336909294},
#  {'name': 'Sympathy', 'score': 0.0599849559366703},
#  {'name': 'Tiredness', 'score': 0.04831625148653984},
#  {'name': 'Triumph', 'score': 0.12037664651870728}]

# %%
df = pd.DataFrame.from_dict(dict["face"]["predictions"][0]["emotions"]) #.sort_values("score", ascending=False)
df
# Out:
#                       name     score
# 0               Admiration  0.219924
# 1                Adoration  0.284119
# 2   Aesthetic Appreciation  0.086447
# 3                Amusement  0.810404
# 4                    Anger  0.021308
# 5                  Anxiety  0.046991
# 6                      Awe  0.071790
# 7              Awkwardness  0.158374
# 8                  Boredom  0.057794
# 9                 Calmness  0.198096
# 10           Concentration  0.103814
# 11           Contemplation  0.054394
# 12               Confusion  0.093683
# 13                Contempt  0.064456
# 14             Contentment  0.290416
# 15                 Craving  0.036932
# 16           Determination  0.046610
# 17          Disappointment  0.055514
# 18                 Disgust  0.031425
# 19                Distress  0.057653
# 20                   Doubt  0.064520
# 21                 Ecstasy  0.180976
# 22           Embarrassment  0.074239
# 23           Empathic Pain  0.030312
# 24            Entrancement  0.084416
# 25                    Envy  0.025140
# 26              Excitement  0.482537
# 27                    Fear  0.032643
# 28                   Guilt  0.022397
# 29                  Horror  0.018800
# 30                Interest  0.382490
# 31                     Joy  0.864149
# 32                    Love  0.551171
# 33               Nostalgia  0.076083
# 34                    Pain  0.052938
# 35                   Pride  0.151144
# 36             Realization  0.088674
# 37                  Relief  0.118858
# 38                 Romance  0.107110
# 39                 Sadness  0.039249
# 40            Satisfaction  0.429101
# 41                  Desire  0.060636
# 42                   Shame  0.028824
# 43     Surprise (negative)  0.017276
# 44     Surprise (positive)  0.029605
# 45                Sympathy  0.059985
# 46               Tiredness  0.048316
# 47                 Triumph  0.120377

# %%
pd.DataFrame.from_dict(dict["face"]["predictions"][0]["emotions"])["name"].tolist()
# Out:
# ['Admiration',
#  'Adoration',
#  'Aesthetic Appreciation',
#  'Amusement',
#  'Anger',
#  'Anxiety',
#  'Awe',
#  'Awkwardness',
#  'Boredom',
#  'Calmness',
#  'Concentration',
#  'Contemplation',
#  'Confusion',
#  'Contempt',
#  'Contentment',
#  'Craving',
#  'Determination',
#  'Disappointment',
#  'Disgust',
#  'Distress',
#  'Doubt',
#  'Ecstasy',
#  'Embarrassment',
#  'Empathic Pain',
#  'Entrancement',
#  'Envy',
#  'Excitement',
#  'Fear',
#  'Guilt',
#  'Horror',
#  'Interest',
#  'Joy',
#  'Love',
#  'Nostalgia',
#  'Pain',
#  'Pride',
#  'Realization',
#  'Relief',
#  'Romance',
#  'Sadness',
#  'Satisfaction',
#  'Desire',
#  'Shame',
#  'Surprise (negative)',
#  'Surprise (positive)',
#  'Sympathy',
#  'Tiredness',
#  'Triumph']

# %%
categories = {
    "Sadness": ["Empathic Pain", "Grief", "Melancholy", "Nostalgia", "Pain", "Sadness"],
    "Happiness": ["Adoration", "Aesthetic Appreciation", "Amusement", "Contentment", "Ecstasy", "Joy", "Love", "Romance", "Satisfaction"],
    "Fear": ["Anxiety", "Fear", "Horror", "Panic", "Paranoia", "Terror"],
    "Anger": ["Anger", "Contempt", "Disgust", "Fury", "Hatred", "Rage"],
    "Surprise": ["Awe", "Surprise (negative)", "Surprise (positive)", "Admiration"],
    "Disgust": ["Contempt", "Disgust", "Loathing", "Nausea", "Revulsion", "Scorn", "Horror"]
}

# %%
stress = ["Anger", "Anxiety", "Distress", "Fear", "Pain", "Sadness", "Tiredness"]
